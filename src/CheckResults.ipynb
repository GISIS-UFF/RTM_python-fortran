# %% [markdown]
# ## Check Results

# %%
# Importing parameters
import parametro
import time
import matplotlib.pyplot as pl
import numpy as np
import multiprocessing as mp
import auxfunctionsmodule as aux
import fortransubroutines as fortran

# %% [markdown]
# ### Check Model used

# %%
# Modelo de Velocidade Usado
#C = aux.readbinaryfile(parametro.Nz,parametro.Nx,parametro.modelosuavizado)
C = aux.readbinaryfile(parametro.Nz,parametro.Nx,parametro.modeloreal)
aux.plotmodel(C,'jet')

# %% [markdown]
# ### Check Seismogram

# %%
# Visualize Seismogram

#select shot to plot
shot = 1
seis_name = parametro.sismogramaobservado + parametro.nome_prin+'sismograma'+str(shot)+'.bin'
print(seis_name)
#Seism = aux.readbinaryfile(parametro.Nt,parametro.Nx,parametro.modeloreal)
# Out:
# ../sismograma/Marmousisismograma1.bin
